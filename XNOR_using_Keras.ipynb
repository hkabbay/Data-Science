# %%
# Create dataset
import pandas as pd
import numpy as np
input = np.array([[0,0] ,[0,1] ,[1,0] ,[1,1]])
target = np.array([[1], [0], [0], [1]])
df = pd.DataFrame(input, columns=['x', 'y'])
df['x XNOR y'] = target
df
# Out:
#    x  y  x XNOR y
# 0  0  0         1
# 1  0  1         0
# 2  1  0         0
# 3  1  1         1

# %%
# Import required libraries
from keras import models
from keras import layers

# %%
# Build model
network = models.Sequential()
network.add(layers.Dense(3, activation='relu', input_dim=2))
network.add(layers.Dense(3, activation='relu'))
network.add(layers.Dense(1, activation='sigmoid'))
network.compile(optimizer='adam',
                loss='mean_squared_error',
                metrics=['binary_accuracy'])

# %%
network.fit(input, target, epochs=600)
# Out:
# Epoch 1/600
# 1/1 [==============================] - 1s 752ms/step - loss: 0.2539 - binary_accuracy: 0.2500
# Epoch 2/600
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2534 - binary_accuracy: 0.2500
# Epoch 3/600
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2530 - binary_accuracy: 0.2500
# Epoch 4/600
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2526 - binary_accuracy: 0.2500
# Epoch 5/600
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2522 - binary_accuracy: 0.2500
# Epoch 6/600
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2518 - binary_accuracy: 0.2500
# Epoch 7/600
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2514 - binary_accuracy: 0.2500
# Epoch 8/600
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2510 - binary_accuracy: 0.2500
# Epoch 9/600
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2507 - binary_accuracy: 0.2500
# Epoch 10/600
# ...

# %%
scores = network.evaluate(input, target)
print("\n%s: %.2f%%" % (network.metrics_names[1], scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 401ms/step - loss: 0.1020 - binary_accuracy: 1.0000
#
# binary_accuracy: 100.00%

# %%
print (network.predict(input).round())
print ("weights", network.layers[0].get_weights()[0])
print ("biases", network.layers[0].get_weights()[1])
# Out:
# [[1.]
#  [0.]
#  [0.]
#  [1.]]
# weights [[ 0.82381225  0.57882726  1.2373483 ]
#  [ 0.06855539  0.40848678 -1.5468721 ]]
# biases [-0.06920487 -0.18212129  0.3401873 ]
